# %% [markdown]
# This notebook will look at splitting polygons into equal parts to localize the outlier identification

# %%
import os
import glob
import math
from processing_tools import *
from shapely.geometry import MultiPoint
from shapely.geometry import Polygon
from shapely.geometry import Point
from shapely.geometry import LineString
from shapely.ops import triangulate
from shapely.ops import unary_union
from shapely.ops import nearest_points
from shapely.ops import voronoi_diagram
from centerline.geometry import Centerline
from new_methods_2 import *
import math

# %%
FZ = gpd.read_file('AZone_48113.shp')
triangles = gpd.read_file(r'U:\klemay\fromAustin\Projects\Hydra\Triangulation\AZone\48113_test\triangles_1m.shp')

azone = FZ.loc[FZ['ZONE'] == 'A']
crs = utm_code(azone)
print(crs)

azone = azone.dissolve().explode().reset_index(0, drop=True)
# Out:
# 32614

# %%
azone.crs.to_epsg()
# Out:
# 4326

# %%
for i, a in azone.iterrows():
    print('Polygon: ', i)
    
    a = g(a.geometry, 4326)
    tri = triangles.sjoin(a)

    tri_pts = tri_zpoints(tri)
    
    # Reproject data
    a_prj = a.to_crs(crs)
    tri_pts_prj = tri_pts.to_crs(crs)

    a_center_pts = centerline_pts(a_prj, crs)
    
    quads = vor_quads(a_center_pts.geometry.to_list(), clip=a_prj, crs=crs)

    tri_buff = g(tri_pts_prj.buffer(1), crs)
    bins = quads.sjoin(tri_buff, how='left')
    bins = bins.groupby(level=0)['index_right'].apply(list)

    for b in bins.index:
        pts = tri_pts_prj.loc[tri_pts_prj.index.isin(bins[b])]
        identify_outliers(pts, b)
        print('QC COMPLETE: ', i)
        print('_______________________________________')
# Out:
# Polygon:  0
#                                              geometry  index_right
# 0   POLYGON ((684271.729 3602963.060, 684271.698 3...          564
# 0   POLYGON ((684271.729 3602963.060, 684271.698 3...          111
# 0   POLYGON ((684271.729 3602963.060, 684271.698 3...          162
# 0   POLYGON ((684271.729 3602963.060, 684271.698 3...          164
# 0   POLYGON ((684271.729 3602963.060, 684271.698 3...          626
# ..                                                ...          ...
# 8   POLYGON ((684738.861 3603184.445, 684739.548 3...          522
# 8   POLYGON ((684738.861 3603184.445, 684739.548 3...            4
# 8   POLYGON ((684738.861 3603184.445, 684739.548 3...         1036
# 8   POLYGON ((684738.861 3603184.445, 684739.548 3...            7
# 8   POLYGON ((684738.861 3603184.445, 684739.548 3...           10
#
# [527 rows x 2 columns]
# Within Range: 0
# QC COMPLETE:  0
# _______________________________________
# Within Range: 1
# QC COMPLETE:  0
# _______________________________________
# Outliers in Bin: 2
#             ELEV                        geometry
# 50    165.884277  POINT (684276.536 3602950.614)
# 102   169.736816  POINT (684367.714 3603024.437)
# 109   167.302109  POINT (684303.152 3603024.934)
# 110   166.759293  POINT (684293.947 3603018.351)
# 123   169.712570  POINT (684321.838 3603057.761)
# 159   167.773972  POINT (684307.988 3603032.576)
# 161   166.490540  POINT (684288.602 3603018.008)
# 170   169.388336  POINT (684320.318 3603054.703)
# 171   169.384888  POINT (684321.849 3603054.713)
# 265   168.913925  POINT (684313.112 3603039.960)
# 270   169.411331  POINT (684320.156 3603052.510)
# 560   166.963852  POINT (684299.090 3603020.546)
# 564   165.857651  POINT (684271.698 3602963.643)
# 68    185.341782  POINT (687298.405 3604778.168)
# 180   182.239990  POINT (687095.764 3604810.314)
# 183   182.988037  POINT (687174.418 3604876.533)
# 184   183.920715  POINT (687231.869 3604827.403)
# 188   184.274857  POINT (687245.596 3604825.172)
# 190   185.318787  POINT (687298.520 3604735.945)
# 326   183.881760  POINT (687153.234 3604757.688)
# 327   182.515884  POINT (687106.988 3604805.501)
# 328   182.881073  POINT (687143.935 3604891.658)
# 329   183.230469  POINT (687153.116 3604884.820)
# 331   183.422241  POINT (687164.583 3604878.914)
# 333   183.205368  POINT (687196.795 3604830.301)
# 335   183.507492  POINT (687214.486 3604828.992)
# 337   185.485046  POINT (687176.576 3604737.078)
# 339   182.817871  POINT (687125.328 3604794.898)
# 340   182.852158  POINT (687114.388 3604803.111)
# 341   182.900269  POINT (687168.397 3604857.605)
# 342   182.712051  POINT (687172.816 3604842.063)
# 344   183.240143  POINT (687178.480 3604836.317)
# 810   181.172165  POINT (687060.385 3604812.760)
# 811   181.720673  POINT (687075.180 3604813.126)
# 819   185.337280  POINT (687300.729 3604785.186)
# 943   185.549957  POINT (687303.916 3604737.794)
# 1083  182.942001  POINT (687170.731 3604866.758)
# 1085  183.234985  POINT (687149.179 3604778.104)
# 1086  183.240753  POINT (687201.547 3604828.791)
# 1090  183.023453  POINT (687133.937 3604795.113)
# 1094  183.036469  POINT (687142.861 3604792.864)
# 1096  183.225037  POINT (687145.179 3604785.856)
# 1517  185.283905  POINT (687300.550 3604790.665)
# 1685  183.085876  POINT (687172.225 3604874.392)
# 1828  183.528717  POINT (687151.386 3604763.028)
# QC COMPLETE:  3
# _______________________________________
# Polygon:  4
#                                              geometry  index_right
# 0   POLYGON ((684929.126 3604704.474, 684929.122 3...         1490
# 0   POLYGON ((684929.126 3604704.474, 684929.122 3...          732
# 0   POLYGON ((684929.126 3604704.474, 684929.122 3...         1491
# 0   POLYGON ((684929.126 3604704.474, 684929.122 3...         1515
# 0   POLYGON ((684929.126 3604704.474, 684929.122 3...         1513
# ..                                                ...          ...
# 8   POLYGON ((685124.636 3604327.112, 685125.786 3...          653
# 8   POLYGON ((685124.636 3604327.112, 685125.786 3...         1057
# 8   POLYGON ((685124.636 3604327.112, 685125.786 3...          296
# 8   POLYGON ((685124.636 3604327.112, 685125.786 3...          446
# 8   POLYGON ((685124.636 3604327.112, 685125.786 3...          447
#
# [770 rows x 2 columns]
# Within Range: 0
# QC COMPLETE:  4
# _______________________________________
# Within Range: 1
# QC COMPLETE:  4
# _______________________________________
# Within Range: 2
# QC COMPLETE:  4
# _______________________________________
# Within Range: 3
# QC COMPLETE:  4
# _______________________________________
# Within Range: 4
# QC COMPLETE:  4
# _______________________________________
# Within Range: 5
# QC COMPLETE:  4
# _______________________________________
# Within Range: 6
# QC COMPLETE:  4
# _______________________________________
# Outliers in Bin: 7
#             ELEV                        geometry
# 655   172.937317  POINT (685138.976 3604289.513)
# 658   172.972488  POINT (685139.698 3604284.581)
# 660   172.950577  POINT (685141.532 3604270.429)
# 662   172.778030  POINT (685139.830 3604259.480)
# 664   172.933243  POINT (685131.692 3604259.425)
# 58    171.310806  POINT (686741.429 3606012.188)
# 361   170.696350  POINT (686747.593 3606130.394)
# 364   171.263000  POINT (686706.416 3606136.598)
# 374   169.545166  POINT (686750.609 3606169.520)
# 378   171.127502  POINT (686750.727 3606137.015)
# 379   170.776627  POINT (686749.040 3606133.786)
# 557   171.458755  POINT (686752.547 3606120.745)
# 559   171.230087  POINT (686750.661 3606124.653)
# 759   170.913895  POINT (686713.474 3606146.508)
# 774   170.457275  POINT (686750.022 3606152.829)
# 1156  170.967957  POINT (686707.860 3606141.237)
# QC COMPLETE:  7
# _______________________________________
# Outliers in Bin: 4
#             ELEV                        geometry
# 131   187.710403  POINT (687347.315 3605573.031)
# 223   187.653870  POINT (687351.799 3605616.737)
# 225   187.642075  POINT (687351.951 3605621.315)
# 229   187.580658  POINT (687351.574 3605629.565)
# 231   185.780518  POINT (687351.853 3605671.742)
# 232   186.160156  POINT (687379.131 3605667.195)
# 233   186.727844  POINT (687376.029 3605657.245)
# 612   185.807098  POINT (687345.495 3605677.588)
# 620   187.717209  POINT (687381.948 3605614.493)
# 626   187.093658  POINT (687377.853 3605642.127)
# 627   186.007050  POINT (687351.642 3605665.510)
# 630   186.257431  POINT (687351.809 3605661.701)
# 631   186.514771  POINT (687351.675 3605657.808)
# 632   186.529800  POINT (687356.098 3605645.304)
# 1011  186.820587  POINT (687384.923 3605669.946)
# QC COMPLETE:  7
# _______________________________________
# Within Range: 5
# QC COMPLETE:  7
# _______________________________________
# Within Range: 6
# QC COMPLETE:  7
# _______________________________________
# Within Range: 7
# QC COMPLETE:  7
# _______________________________________
# Outliers in Bin: 8
#             ELEV                        geometry
# 33    186.444778  POINT (687392.761 3605712.879)
# 117   185.570160  POINT (687386.129 3605721.471)
# 120   186.493484  POINT (687392.660 3605709.883)
# 217   185.967438  POINT (687386.664 3605687.029)
# 517   185.815720  POINT (687392.071 3605694.975)
# 610   185.654358  POINT (687324.062 3605713.147)
# 611   185.878784  POINT (687342.186 3605681.117)
# 612   185.807098  POINT (687345.495 3605677.588)
# 913   186.650208  POINT (687394.290 3605699.223)
# 1011  186.820587  POINT (687384.923 3605669.946)
# QC COMPLETE:  7
# _______________________________________
# Polygon:  8
#                                              geometry  index_right
# 0   POLYGON ((688298.492 3606748.845, 688279.344 3...         2684
# 0   POLYGON ((688298.492 3606748.845, 688279.344 3...          841
# 0   POLYGON ((688298.492 3606748.845, 688279.344 3...         2698
# 0   POLYGON ((688298.492 3606748.845, 688279.344 3...          400
# 0   POLYGON ((688298.492 3606748.845, 688279.344 3...          766
# ..                                                ...          ...
# 8   POLYGON ((690547.637 3606692.896, 690547.917 3...         5515
# 8   POLYGON ((690547.637 3606692.896, 690547.917 3...         1802
# 8   POLYGON ((690547.637 3606692.896, 690547.917 3...         1804
# 8   POLYGON ((690547.637 3606692.896, 690547.917 3...         1772
# 8   POLYGON ((690547.637 3606692.896, 690547.917 3...         1488
#
# [1878 rows x 2 columns]
# Outliers in Bin: 0
#             ELEV                        geometry
# 6  POLYGON ((693229.656 3607538.995, 693232.355 3...           36
# 6  POLYGON ((693229.656 3607538.995, 693232.355 3...           61
# 6  POLYGON ((693229.656 3607538.995, 693232.355 3...           60
# 7  POLYGON ((693194.544 3607533.939, 693204.441 3...           26
# 7  POLYGON ((693194.544 3607533.939, 693204.441 3...           65
# 7  POLYGON ((693194.544 3607533.939, 693204.441 3...           24
# 7  POLYGON ((693194.544 3607533.939, 693204.441 3...           37
# 7  POLYGON ((693194.544 3607533.939, 693204.441 3...           63
# 7  POLYGON ((693194.544 3607533.939, 693204.441 3...           72
# 8  POLYGON ((693260.479 3607545.902, 693261.196 3...           19
# 8  POLYGON ((693260.479 3607545.902, 693261.196 3...           18
# 8  POLYGON ((693260.479 3607545.902, 693261.196 3...           60
# 8  POLYGON ((693260.479 3607545.902, 693261.196 3...           59
# 8  POLYGON ((693260.479 3607545.902, 693261.196 3...           58
# 8  POLYGON ((693260.479 3607545.902, 693261.196 3...           53
# Within Range: 0
# QC COMPLETE:  9
# _______________________________________
# Within Range: 1
# QC COMPLETE:  9
# _______________________________________
# Within Range: 2
# QC COMPLETE:  9
# _______________________________________
# Within Range: 3
# QC COMPLETE:  9
# _______________________________________
# Within Range: 4
# QC COMPLETE:  9
# _______________________________________
# Within Range: 5
# QC COMPLETE:  9
# _______________________________________
# Within Range: 6
# QC COMPLETE:  9
# _______________________________________
# Within Range: 7
# QC COMPLETE:  9
# _______________________________________
# Within Range: 8
# QC COMPLETE:  9
# _______________________________________
# Polygon:  10
#                                              geometry  index_right
# 0   POLYGON ((693466.174 3607821.614, 693465.753 3...          169
# 0   POLYGON ((693466.174 3607821.614, 693465.753 3...          248
# 0   POLYGON ((693466.174 3607821.614, 693465.753 3...           62
# 0   POLYGON ((693466.174 3607821.614, 693465.753 3...           17
# 0   POLYGON ((693466.174 3607821.614, 693465.753 3...           66
# ..                                                ...          ...
# 8   POLYGON ((693455.870 3607648.235, 693455.966 3...          381
# 8   POLYGON ((693455.870 3607648.235, 693455.966 3...          152
# 8   POLYGON ((693455.870 3607648.235, 693455.966 3...          371
# 8   POLYGON ((693455.870 3607648.235, 693455.966 3...          370
# 8   POLYGON ((693455.870 3607648.235, 693455.966 3...          384
#
# [243 rows x 2 columns]
# Within Range: 0
# QC COMPLETE:  10
# _______________________________________
# Within Range: 1
# QC COMPLETE:  10
# _______________________________________
# Within Range: 2
# QC COMPLETE:  10
# _______________________________________
# Within Range: 3
# QC COMPLETE:  10
# _______________________________________
# Within Range: 4
# QC COMPLETE:  10
# _______________________________________
# Within Range: 5
# QC COMPLETE:  10
# _______________________________________
# Within Range: 6
# QC COMPLETE:  10
# _______________________________________
# Within Range: 7
# QC COMPLETE:  10
# _______________________________________
# Within Range: 8
# QC COMPLETE:  10
# _______________________________________
# Polygon:  11
#                                             geometry  index_right
# 0  POLYGON ((693487.670 3608048.923, 693482.379 3...          2.0
# 0  POLYGON ((693487.670 3608048.923, 693482.379 3...          0.0
# 0  POLYGON ((693487.670 3608048.923, 693482.379 3...         13.0
# 1  POLYGON ((693506.409 3608018.705, 693511.696 3...          3.0
# 2  POLYGON ((693489.511 3608040.816, 693487.670 3...          NaN
# 3  POLYGON ((693492.206 3608028.949, 693491.069 3...          NaN
# 4  POLYGON ((693495.155 3608022.762, 693506.409 3...         16.0
# 4  POLYGON ((693495.155 3608022.762, 693506.409 3...          5.0
# 4  POLYGON ((693495.155 3608022.762, 693506.409 3...         10.0
# 4  POLYGON ((693495.155 3608022.762, 693506.409 3...          6.0
# 5  POLYGON ((693491.069 3608033.957, 693489.511 3...          NaN
# 6  POLYGON ((693495.296 3608022.824, 693495.155 3...          NaN
# 7  POLYGON ((693516.575 3608033.260, 693518.466 3...          NaN
# 8  POLYGON ((693495.296 3608022.824, 693511.696 3...          NaN
# Outliers in Bin: 0
#          ELEV                        geometry
# 0  235.420441  POINT (693482.379 3608072.226)
# QC COMPLETE:  11
# _______________________________________
# Within Range: 1
# QC COMPLETE:  11
# _______________________________________
# Within Range: 2
# QC COMPLETE:  11
# _______________________________________
# Within Range: 3
# QC COMPLETE:  11
# _______________________________________
# Outliers in Bin: 4
#           ELEV                        geometry
# 10  234.267975  POINT (693506.111 3608006.893)
# QC COMPLETE:  11
# _______________________________________
# Within Range: 5
# QC COMPLETE:  11
# _______________________________________
# Within Range: 6
# QC COMPLETE:  11
# _______________________________________
# Within Range: 7
# QC COMPLETE:  11
# _______________________________________
# Within Range: 8
# QC COMPLETE:  11
# _______________________________________
# Polygon:  12
#                                              geometry  index_right
# 0   POLYGON ((693432.758 3609559.115, 693431.964 3...         1485
# 0   POLYGON ((693432.758 3609559.115, 693431.964 3...         2970
# 0   POLYGON ((693432.758 3609559.115, 693431.964 3...         1407
# 0   POLYGON ((693432.758 3609559.115, 693431.964 3...         4537
# 0   POLYGON ((693432.758 3609559.115, 693431.964 3...         2842
# ..                                                ...          ...
# 8   POLYGON ((693515.131 3609707.183, 693515.121 3...         1623
# 8   POLYGON ((693515.131 3609707.183, 693515.121 3...         3188
# 8   POLYGON ((693515.131 3609707.183, 693515.121 3...           56
# 8   POLYGON ((693515.131 3609707.183, 693515.121 3...         3141
# 8   POLYGON ((693515.131 3609707.183, 693515.121 3...           11
#
# [1569 rows x 2 columns]
# Within Range: 0
# QC COMPLETE:  12
# _______________________________________
# Within Range: 1
# QC COMPLETE:  12
# _______________________________________
# Within Range: 2
# QC COMPLETE:  12
# _______________________________________
# Outliers in Bin: 3
#             ELEV                        geometry
# 14    229.375946  POINT (693450.109 3608583.653)
# 15    232.687958  POINT (693447.009 3608595.853)
# 59    228.285645  POINT (693503.159 3608650.976)
# 70    228.438095  POINT (693451.654 3608583.683)
# 72    229.597107  POINT (693448.547 3608591.289)
# 73    230.517731  POINT (693448.519 3608595.859)
# 159   228.471680  POINT (693501.578 3608660.115)
# 182   228.203278  POINT (693451.596 3608589.786)
# 183   228.291046  POINT (693451.597 3608591.289)
# 187   231.715546  POINT (693448.447 3608614.155)
# 358   228.397583  POINT (693498.528 3608661.637)
# 393   229.375427  POINT (693449.949 3608617.197)
# 395   229.465530  POINT (693452.967 3608626.372)
# 396   228.882095  POINT (693454.464 3608629.413)
# 14825  146.169388  POINT (691237.386 3618313.442)
# 14914  147.937607  POINT (691326.076 3618252.864)
# 14920  147.046112  POINT (691283.227 3618287.722)
#
# [128 rows x 2 columns]
# QC COMPLETE:  18
# _______________________________________
# Within Range: 5
# QC COMPLETE:  18
# _______________________________________
# Outliers in Bin: 6
#              ELEV                        geometry
# 203    160.583527  POINT (692214.458 3618308.753)
# 510    160.204590  POINT (692214.472 3618307.232)
# 511    160.327637  POINT (692220.584 3618304.224)
# 512    160.056946  POINT (692228.225 3618299.695)
# 976    160.253845  POINT (692215.995 3618305.711)
# ...           ...                             ...
# 15050  160.247818  POINT (692252.726 3618276.931)
# 15767  161.756638  POINT (692271.496 3618168.796)
# 15775  161.950012  POINT (692289.826 3618161.245)
# 15858  162.167160  POINT (692308.122 3618159.815)
# 15869  162.063034  POINT (692283.716 3618161.216)
#
# [87 rows x 2 columns]
# QC COMPLETE:  18
# _______________________________________
# Outliers in Bin: 7
#              ELEV                        geometry
# 15     171.681030  POINT (692923.191 3617988.859)
# 17     171.120331  POINT (692924.714 3617987.349)
# 86     172.056152  POINT (692918.610 3617988.830)
# 87     171.575470  POINT (692920.152 3617985.799)
# 90     172.442291  POINT (692987.699 3617882.441)
# ...           ...                             ...
# 11778  171.564072  POINT (692969.386 3617885.421)
# 12317  171.690689  POINT (692882.747 3617830.147)
# 12330  169.038940  POINT (692934.173 3617920.307)
# 12336  171.998642  POINT (692881.106 3617859.098)
# 12337  172.167877  POINT (692904.125 3617822.615)
#
# [162 rows x 2 columns]
# QC COMPLETE:  18
# _______________________________________
# Outliers in Bin: 8
#              ELEV                        geometry
# 23     199.543854  POINT (693426.143 3616064.333)
# 26     200.049194  POINT (693410.536 3616075.681)
# 119    203.746262  POINT (693429.328 3616070.289)
# 120    198.609894  POINT (693421.703 3616067.665)
# 121    200.063705  POINT (693410.945 3616075.439)
# ...           ...                             ...
# 14084  199.224823  POINT (693402.153 3616244.220)
# 14101  201.541733  POINT (693350.171 3616280.563)
# 14118  199.073334  POINT (693370.235 3616224.258)
# 14127  198.787399  POINT (693392.627 3616328.007)
# 14128  200.754913  POINT (693344.034 3616288.164)
#
# [296 rows x 2 columns]
# QC COMPLETE:  18
# _______________________________________
# Polygon:  19
#                                              geometry  index_right
# 0   POLYGON ((692901.876 3619789.243, 692862.730 3...          302
# 0   POLYGON ((692901.876 3619789.243, 692862.730 3...          540
# 0   POLYGON ((692901.876 3619789.243, 692862.730 3...         1998
# 0   POLYGON ((692901.876 3619789.243, 692862.730 3...         3459
# 0   POLYGON ((692901.876 3619789.243, 692862.730 3...          102
# ..                                                ...          ...
# 8   POLYGON ((693011.959 3619474.553, 693011.976 3...          805
# 8   POLYGON ((693011.959 3619474.553, 693011.976 3...         2263
# 8   POLYGON ((693011.959 3619474.553, 693011.976 3...          491
# 8   POLYGON ((693011.959 3619474.553, 693011.976 3...          806
# 8   POLYGON ((693011.959 3619474.553, 693011.976 3...          814
#
# [1462 rows x 2 columns]
# Within Range: 0
# QC COMPLETE:  19
# _______________________________________
# Outliers in Bin: 1
#             ELEV                        geometry
# 6     152.888168  POINT (692924.682 3620224.869)
# 7     152.645325  POINT (692926.220 3620221.761)
# 25    152.857224  POINT (692752.147 3620291.139)
# 27    152.915741  POINT (692752.119 3620295.714)
# 32    150.446732  POINT (692879.469 3620280.759)
# ...          ...                             ...
# 3093  151.209610  POINT (692913.975 3620238.532)
# 3094  151.136505  POINT (692915.535 3620236.665)
# 3101  150.713623  POINT (692925.015 3620211.076)
# 3292  150.910919  POINT (692926.560 3620203.470)
# 3293  151.678925  POINT (692928.097 3620200.445)
#
# [70 rows x 2 columns]
# QC COMPLETE:  19
# _______________________________________
# Within Range: 2
# QC COMPLETE:  19
# _______________________________________
# Within Range: 3
# QC COMPLETE:  19
# _______________________________________
# Within Range: 4
# QC COMPLETE:  19
# _______________________________________
# Outliers in Bin: 5
#             ELEV                        geometry
# 209   159.394867  POINT (692982.814 3619847.123)
# 210   158.250595  POINT (692982.833 3619844.069)
# 427   159.378250  POINT (692981.277 3619850.154)
# 428   158.473358  POINT (692981.296 3619847.100)
# 430   157.223694  POINT (692981.300 3619844.039)
# 431   156.780396  POINT (692978.313 3619831.858)
# 432   156.840652  POINT (692978.318 3619830.325)
# 433   157.370453  POINT (692978.332 3619828.804)
# 662   156.644821  POINT (692965.750 3619914.095)
# 669   157.304291  POINT (692978.216 3619851.652)
# 679   158.056183  POINT (692972.257 3619822.672)
# 680   157.023392  POINT (692967.732 3619811.988)
# 681   156.998123  POINT (692966.241 3619804.353)
# 682   157.594376  POINT (692966.308 3619795.208)
# 683   158.400024  POINT (692966.315 3619789.111)
# 887   156.835220  POINT (692964.769 3619795.196)
# 1337  156.629944  POINT (692969.190 3619822.666)
# 1886  158.768250  POINT (692979.754 3619850.142)
# 2137  157.387909  POINT (692972.237 3619825.744)
# 3348  157.314301  POINT (692981.314 3619842.530)
# 3591  158.749695  POINT (692979.740 3619851.663)
# 3596  157.783936  POINT (692973.771 3619825.738)
# 3807  157.421585  POINT (692963.292 3619784.530)
# 4244  156.787277  POINT (692955.136 3619901.861)
# 4256  157.179291  POINT (692969.234 3619819.606)
# 4267  156.713058  POINT (692953.622 3619898.795)
# QC COMPLETE:  19
# _______________________________________
# Within Range: 6
# QC COMPLETE:  19
# _______________________________________
# Within Range: 7
# QC COMPLETE:  19
# _______________________________________
# Outliers in Bin: 8
#             ELEV                        geometry
# 8     179.637100  POINT (693331.759 3619239.418)
# 63    162.023392  POINT (693258.175 3619298.113)
# 64    168.163101  POINT (693283.558 3619267.881)
# 66    162.188980  POINT (693236.999 3619261.416)
# 211   161.987564  POINT (693253.591 3619301.132)
# ...          ...                             ...
# 4183  162.648438  POINT (693184.883 3619326.733)
# 4187  162.073364  POINT (693197.145 3619313.077)
# 4196  162.067230  POINT (693169.782 3619296.168)
# 4197  161.858170  POINT (693187.957 3619320.642)
# 4206  162.228012  POINT (693210.892 3619305.504)
#
# [114 rows x 2 columns]
# QC COMPLETE:  19
# _______________________________________
# Polygon:  20
#                                              geometry  index_right
# 0   POLYGON ((693467.486 3621488.879, 693467.501 3...         3207
# 0   POLYGON ((693467.486 3621488.879, 693467.501 3...         1320
# 0   POLYGON ((693467.486 3621488.879, 693467.501 3...         1321
# 0   POLYGON ((693467.486 3621488.879, 693467.501 3...         1369
# 0   POLYGON ((693467.486 3621488.879, 693467.501 3...         1368
# ..                                                ...          ...
# 8   POLYGON ((693491.386 3620692.553, 693494.006 3...          230
# 8   POLYGON ((693491.386 3620692.553, 693494.006 3...           86
# 8   POLYGON ((693491.386 3620692.553, 693494.006 3...          228
# 8   POLYGON ((693491.386 3620692.553, 693494.006 3...          444
# 8   POLYGON ((693491.386 3620692.553, 693494.006 3...           87
#
# [1899 rows x 2 columns]
# Within Range: 0
# QC COMPLETE:  20
# _______________________________________
# Within Range: 1
# QC COMPLETE:  20
# _______________________________________
# Within Range: 2
# QC COMPLETE:  20
# _______________________________________
# Within Range: 3
# QC COMPLETE:  20
# _______________________________________
# Within Range: 4
# QC COMPLETE:  20
# _______________________________________
# Within Range: 5
# QC COMPLETE:  20
# _______________________________________
# Outliers in Bin: 6
#             ELEV                        geometry
# 732   154.789474  POINT (693512.339 3620681.761)
# 1079  154.826462  POINT (693516.875 3620687.869)
# 1080  154.462067  POINT (693513.839 3620686.324)
# 1081  154.352005  POINT (693512.315 3620686.330)
# 1520  155.148087  POINT (693554.897 3620709.384)
# ...          ...                             ...
# 5557  155.059845  POINT (693505.952 3620744.227)
# 5564  154.379181  POINT (693481.697 3620716.662)
# 5577  154.356827  POINT (693480.160 3620719.717)
# 5587  154.294739  POINT (693478.617 3620721.232)
# 5606  154.226486  POINT (693494.018 3620687.758)
#
# [73 rows x 2 columns]
# QC COMPLETE:  20
# _______________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
#      24 for b in bins.index:
#      25     pts = tri_pts_prj.loc[tri_pts_prj.index.isin(bins[b])]
# ---> 26     identify_outliers(pts, b)
#      27     print('QC COMPLETE: ', i)
#      28     print('_______________________________________')
#
# Input In [23], in identify_outliers(bin0, bid)
#       1 def identify_outliers(bin0, bid):
#       2     if bin0.std()[0] > 1:
#       3         # Identify the skewness
# ----> 4         hrange = np.abs(bin0.max()[0] - bin0.mean()[0])
#       5         lrange = np.abs(bin0.mean()[0] - bin0.min()[0])
#       7         if hrange > lrange:
#
# File D:\mini-forge\envs\geopandas\lib\site-packages\pandas\core\generic.py:11212, in NDFrame._add_numeric_operations.<locals>.max(self, axis, skipna, level, numeric_only, **kwargs)
#   11192 @doc(  # type: ignore[misc]
#   11193     _num_doc,
#   11194     desc="Return the maximum of the values over the requested axis.\n\n"
#    (...)
#   11210     **kwargs,
#   11211 ):
# > 11212     return NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#
# File D:\mini-forge\envs\geopandas\lib\site-packages\pandas\core\generic.py:10669, in NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#   10661 def max(
#   10662     self,
#   10663     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   10667     **kwargs,
#   10668 ):
# > 10669     return self._stat_function(
#   10670         "max",
#   10671         nanops.nanmax,
#   10672         axis,
#   10673         skipna,
#   10674         level,
#   10675         numeric_only,
#   10676         **kwargs,
#   10677     )
#
# File D:\mini-forge\envs\geopandas\lib\site-packages\pandas\core\generic.py:10639, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10629     warnings.warn(
#   10630         "Using the level keyword in DataFrame and Series aggregations is "
#   10631         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   10634         stacklevel=find_stack_level(),
#   10635     )
#   10636     return self._agg_by_level(
#   10637         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10638     )
# > 10639 return self._reduce(
#   10640     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10641 )
#
# File D:\mini-forge\envs\geopandas\lib\site-packages\pandas\core\frame.py:10034, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10026         if name in ["all", "any"]:
#   10027             arg_name = "bool_only"
#   10028         warnings.warn(
#   10029             "Dropping of nuisance columns in DataFrame reductions "
#   10030             f"(with '{arg_name}=None') is deprecated; in a future "
#   10031             "version this will raise TypeError.  Select only valid "
#   10032             "columns before calling the reduction.",
#   10033             FutureWarning,
# > 10034             stacklevel=find_stack_level(),
#   10035         )
#   10037     return out
#   10039 assert numeric_only is None
#
# File D:\mini-forge\envs\geopandas\lib\site-packages\pandas\util\_exceptions.py:32, in find_stack_level()
#      27 def find_stack_level() -> int:
#      28     """
#      29     Find the first place in the stack that is not inside pandas
#      30     (tests notwithstanding).
#      31     """
# ---> 32     stack = inspect.stack()
#      34     import pandas as pd
#      36     pkg_dir = os.path.dirname(pd.__file__)
#
# File D:\mini-forge\envs\geopandas\lib\inspect.py:1678, in stack(context)
#    1676 def stack(context=1):
#    1677     """Return a list of records for the stack above the caller's frame."""
# -> 1678     return getouterframes(sys._getframe(1), context)
#
# File D:\mini-forge\envs\geopandas\lib\inspect.py:1655, in getouterframes(frame, context)
#    1653 framelist = []
#    1654 while frame:
# -> 1655     frameinfo = (frame,) + getframeinfo(frame, context)
#    1656     framelist.append(FrameInfo(*frameinfo))
#    1657     frame = frame.f_back
#
# File D:\mini-forge\envs\geopandas\lib\inspect.py:1625, in getframeinfo(frame, context)
#    1622 if not isframe(frame):
#    1623     raise TypeError('{!r} is not a frame or traceback object'.format(frame))
# -> 1625 filename = getsourcefile(frame) or getfile(frame)
#    1626 if context > 0:
#    1627     start = lineno - 1 - context//2
#
# File D:\mini-forge\envs\geopandas\lib\inspect.py:826, in getsourcefile(object)
#     823 elif any(filename.endswith(s) for s in
#     824              importlib.machinery.EXTENSION_SUFFIXES):
#     825     return None
# --> 826 if os.path.exists(filename):
#     827     return filename
#     828 # only return a non-existent filename if the module has a PEP 302 loader
#
# File D:\mini-forge\envs\geopandas\lib\genericpath.py:19, in exists(path)
#      17 """Test whether a path exists.  Returns False for broken symbolic links"""
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#      21     return False
#
# KeyboardInterrupt:

# %%
def tri_zpoints(df):

    crs = df.crs.to_epsg()

    df0 = df[['pt_0_LAT', 'pt_0_LONG', 'pt_0_Z']]
    df1 = df[['pt_1_LAT', 'pt_1_LONG', 'pt_1_Z']]
    df2 = df[['pt_2_LAT', 'pt_2_LONG', 'pt_2_Z']]

    pt0 = gpd.GeoDataFrame(df0, geometry=gpd.points_from_xy(df0['pt_0_LONG'], df0['pt_0_LAT']), crs=crs)[['pt_0_Z', 'geometry']]
    pt1 = gpd.GeoDataFrame(df1, geometry=gpd.points_from_xy(df1['pt_1_LONG'], df1['pt_1_LAT']), crs=crs)[['pt_1_Z', 'geometry']]
    pt2 = gpd.GeoDataFrame(df2, geometry=gpd.points_from_xy(df2['pt_2_LONG'], df2['pt_2_LAT']), crs=crs)[['pt_2_Z', 'geometry']]

    pt0.rename(columns={'pt_0_Z': 'ELEV'}, inplace=True)
    pt1.rename(columns={'pt_1_Z': 'ELEV'}, inplace=True)
    pt2.rename(columns={'pt_2_Z': 'ELEV'}, inplace=True)

    pts = pd.concat([pt0, pt1, pt2], ignore_index=True)

    pts_no_dups = pts.drop_duplicates('geometry')

    return pts_no_dups

# %%
#osmnx.utils_geo._quadrat_cut_geometry(geometry, quadrat_width, min_num=3

df = gpd.read_file('a1_poly.shp')
crs = utm_code(df)
crs
# Out:
# '32614'

# %%
def centerline_pts(df, crs):
    c = Centerline(df.geometry[0], interpolation_distance=10)
    c = g(c, crs)
    
    c['pts'] = c.apply(lambda x: [x.geometry.interpolate(i/10, normalized=True) for i in range(1, 10)], axis=1)

    return g(c['pts'][0], crs)

# %%
def vor_quads(pt_ls, crs, clip=None):
    vor_raw = voronoi_diagram(MultiPoint(pt_ls))
    vor = g(vor_raw, crs).explode().explode() # geometry colleciton --> MultiPolygon --> Polygons

    if clip is not None:
        vor = vor.overlay(clip)
    
    return vor

# %%
def identify_outliers(bin0, bid):
    if bin0.std()[0] > 1:
        # Identify the skewness
        hrange = np.abs(bin0.max()[0] - bin0.mean()[0])
        lrange = np.abs(bin0.mean()[0] - bin0.min()[0])
        
        if hrange > lrange:
            print('Outliers in Bin:', bid)
            print(bin0.loc[bin0['ELEV'] > bin0.describe().T['75%'][0]])
        else:
            print('Outliers in Bin:', bid)
            print(bin0.loc[bin0['ELEV'] < bin0.describe().T['25%'][0]])
            
    else:    
        print('Within Range:', bid)

# %%
df = df[['FIPS', 'geometry']]
df = df.to_crs(crs)

# %%
df
# Out:
#     FIPS                                           geometry
# 0  48113  POLYGON ((684758.104 3603143.727, 684761.217 3...

# %%
center = Centerline(df.geometry[0], interpolation_distance=10)
center = g(center, crs)

# %%
center['pts'] = center.apply(lambda x: [x.geometry.interpolate(i/10, normalized=True) for i in range(1, 10)], axis=1)
center
# Out:
#                                             geometry  \
# 0  MULTILINESTRING ((684193.609 3603059.184, 6841...
#
#                                                  pts
# 0  [POINT (684218.08273676 3603052.5964880493), P...

# %%
center['pts'][0]
# Out:
# [<shapely.geometry.point.Point at 0x1e00246b910>,
#  <shapely.geometry.point.Point at 0x1e00246b3a0>,
#  <shapely.geometry.point.Point at 0x1e00246add0>,
#  <shapely.geometry.point.Point at 0x1e002469390>,
#  <shapely.geometry.point.Point at 0x1e00246aad0>,
#  <shapely.geometry.point.Point at 0x1e00246aa40>,
#  <shapely.geometry.point.Point at 0x1e00246b040>,
#  <shapely.geometry.point.Point at 0x1e00246b7c0>,
#  <shapely.geometry.point.Point at 0x1e00246bee0>]

# %%
pt_geom = center['pts'][0]
pts = g(pt_geom, crs)

# %%
vor_raw = voronoi_diagram(MultiPoint(pt_geom))

# %%
vor = g(vor_raw, crs).explode().explode()
vor.head()
# Out:
#                                                 geometry
# 0 0 0  POLYGON ((683757.594 3602522.637, 683757.594 3...
#   1 0  POLYGON ((683840.778 3602522.637, 684279.602 3...
#   2 0  POLYGON ((684279.602 3603051.849, 684387.178 3...
#   3 0  POLYGON ((684351.078 3602522.637, 684396.494 3...
#   4 0  POLYGON ((685139.061 3602552.209, 684494.840 3...

# %%
vor = vor.overlay(df)

# %%
pts = gpd.read_file('zpoints_1m_projected_a1.shp')
pts_buff = g(pts.buffer(1), crs)

# %%
bins = vor.sjoin(pts_buff, how='left')
#bins.to_file('bins.shp')
bins
# Out:
#      FIPS                                           geometry  index_right
# 0   48113  POLYGON ((684241.320 3603005.682, 684237.375 3...           53
# 0   48113  POLYGON ((684241.320 3603005.682, 684237.375 3...           54
# 0   48113  POLYGON ((684241.320 3603005.682, 684237.375 3...           55
# 0   48113  POLYGON ((684241.320 3603005.682, 684237.375 3...          340
# 0   48113  POLYGON ((684241.320 3603005.682, 684237.375 3...          341
# ..    ...                                                ...          ...
# 8   48113  POLYGON ((684497.382 3602976.250, 684499.017 3...           17
# 8   48113  POLYGON ((684497.382 3602976.250, 684499.017 3...          472
# 8   48113  POLYGON ((684497.382 3602976.250, 684499.017 3...           68
# 8   48113  POLYGON ((684497.382 3602976.250, 684499.017 3...          501
# 8   48113  POLYGON ((684497.382 3602976.250, 684499.017 3...          414
#
# [522 rows x 3 columns]

# %%
# groupby bin id
bins = bins.groupby(level=0)['index_right'].apply(list)
bins
# Out:
# 0    [53, 54, 55, 340, 341, 56, 342, 57, 295, 9, 29...
# 1    [8, 468, 304, 303, 51, 78, 79, 339, 52, 80, 81...
# 2    [42, 43, 331, 44, 332, 45, 333, 46, 49, 76, 13...
# 3    [6, 23, 22, 24, 313, 72, 321, 352, 73, 473, 31...
# 4    [179, 178, 239, 177, 238, 498, 176, 241, 437, ...
# 5    [7, 35, 36, 324, 325, 37, 38, 326, 39, 327, 40...
# 6    [184, 185, 412, 183, 411, 182, 248, 247, 257, ...
# 7    [285, 462, 286, 463, 421, 504, 215, 422, 423, ...
# 8    [14, 307, 471, 16, 308, 67, 347, 121, 120, 119...
# Name: index_right, dtype: object

# %%
""" the following will be the script used to pipeline and validate the elevation values within each quadrant """
def identify_outliers(bin0, id):
    if bin0.std()[0] > 1:
        hrange = np.abs(bin0.max()[0] - bin0.mean()[0])
        lrange = np.abs(bin0.mean()[0] - bin0.min()[0])
        
        if hrange > lrange:
            print('Outliers in Quad:', id)
            print(bin0.loc[bin0['ELEV'] > bin0.describe().T['75%'][0]])
        else:
            print('Outliers in Quad:', id)
            print(bin0.loc[bin0['ELEV'] < bin0.describe().T['25%'][0]])
            
    else:    
        print('Within Range:', id)


for b in bins.index:
    pts = pts.loc[pts.index.isin(bins[b])]
    identify_outliers(pts, b)
# Out:
# Within Range: 0
# Within Range: 1
# Within Range: 2
# Within Range: 3
# Within Range: 4
# Within Range: 5
# Within Range: 6
# Within Range: 7
# Within Range: 8
