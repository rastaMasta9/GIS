# %%
from new_methods import *

# %%
process_dict = {'CO': ['08093', '08119'],
                'FL': ['12086', '12011', '12087', '12051', '12099'],
                'LA': ['22071', '22051', '22075', '22087', '22103', '22057', '22089', '22095', '22105']}

for co, ls in process_dict.items():
    for l in ls:
        AE = False
        s = datetime.now()
        for fi in glob.glob(f'{co}_FZ\*{l}.shp'):
            selFZ = gpd.read_file(os.path.abspath(fi))
            print('Processing', fi)
            
        for fi in glob.glob(f'{co}_BFEs\*{l}.shp'):
            selBFE = gpd.read_file(os.path.abspath(fi))
            print('Processing', fi)
        # determine correct UTM projection from flood zone
        crs = utm_code(selFZ)

        print('AE Zones')
        # Locate all AE and A* zones with no Static values
        sel_ae = selFZ.loc[(selFZ['ZONE'].str.contains('A.')) & 
        (selFZ['ZONE'] != 'A99') & 
        (selFZ['ZONE'] != 'AO') & 
        (selFZ['ZONE'] != 'AR')
        ]

        sel_ae_dynamic = sel_ae.loc[sel_ae['BFE_STATIC'] == -9999.0]
        sel_ae_dis = sel_ae_dynamic.dissolve(by='FIPS')
        sel_ae_dis.to_crs(crs, inplace=True)
        ae_zones = sel_ae_dis[['geometry']]
        ae_zones.reset_index(inplace=True)

        print('A Zones')
        sel_a = selFZ.loc[selFZ['ZONE'] == 'A']

        print('X500 Zones')
        # Locate x500 and prep
        sel_x = selFZ.loc[selFZ['ZONE'] == 'X500']
        if len(sel_x) > 0:
            x = x.dissolve().explode().to_crs(crs)[['geometry']]
            x = x.reset_index(0, drop=True)
            x.to_file(f'{l}_x500.shp')

        
        # If there are no AE or A* Zones (i.e. dataframe is empty, continue on to the next county)
        if len(ae_zones) > 0:
            AE = True
            print('Cleaning BFEs')
            # Reproject BFEs 
            selBFE.to_crs(crs, inplace=True)
            sel_bfe = selBFE[['ELEV', 'geometry']]
            sel_bfe = sel_bfe.drop_duplicates('geometry') # * delete late

            """ If main Index joins with other Indices, this means that a BFE is broken
             up into several linestrings. This cleaning process attempts to merge
            all linestrings into one per BFE """

            bfe_bfe = sel_bfe.sjoin(sel_bfe, how='left')
            bfe_bfe.reset_index(inplace=True)

            brok = bfe_bfe.loc[bfe_bfe['index'] != bfe_bfe['index_right']]
            sel_bfe.reset_index(inplace=True)

            if len(brok) > 0:
                # df with both main geometry and adjacent geoms
                fix = brok.merge(sel_bfe, left_on='index_right', right_on='index')

                """Locating and gathering adjacent geometries to linestrings in the middle. These will account for 
                BFEs that have been broken up more than twice """
                # Series with indice count of spatial join
                vals = fix['index_x'].value_counts()

                # Obtaining the Indices that touch more than one linestring
                mid = fix.loc[fix['index_x'].isin(vals.index[vals.gt(1)])]

                # Groupby Main Index and collect adj. geoms into list
                mid_gb = mid.groupby('index_x')['geometry_y'].apply(list)

                # Groupby Main Index and collect adj. indices into list
                mid_adj = mid.groupby('index_x')['index_right'].apply(list)

                # Build df from groupby series to join and obtain key geometry
                mid_df = pd.DataFrame(mid_gb)
                mid_df.reset_index(inplace=True)
                mid_join = mid_df.merge(sel_bfe, left_on='index_x', right_index=True)

                """ Adjacent IDS to Middle that need to be removed since these will be apart of the 3 linestring merge """
                # Creating list of Main Indices that touch more than one linestring
                mid_ids = mid['index_x'].drop_duplicates().to_list()

                # Creating list of adjacent indices that touch Main Index
                adj_list = [ids for m in mid_adj.to_list() for ids in m]
                adj_list = adj_list + mid_ids  

                """ These should be 2 linestrings ONLY """
                # Remove ids from adj_list, leaving ids that touch only One other linestring
                fix_rem = fix.loc[~fix['index_x'].isin(adj_list)]

                """ Correct 2 linestring breaks """
                fix_rem['new_geom'] = fix_rem.apply(lambda x: linemerge(list((x.geometry_x, x.geometry_y))), axis=1 )
                fix_df = fix_rem[['index_x', 'ELEV_left', 'new_geom']].rename(columns={'index_x': 'index', 'new_geom': 'geometry', 'ELEV_left': 'ELEV'}).set_geometry('geometry', crs=crs)

                # This removes the other pair in the 1-to-1 join
                fix_df = fix_df.drop_duplicates('geometry')

                """ Correct 3 (or more) linestring breaks """
                if len(mid_join) > 0:
                    mid_join['new_geom'] = mid_join.apply(lambda x: linemerge(x['geometry_y'] + [x['geometry']]), axis=1)
                    mid_join = mid_join[['index_x', 'ELEV', 'new_geom']].rename(columns={'index_x': 'index', 'new_geom': 'geometry'}).set_geometry('geometry', crs=crs)

                    bfe_cleaned = pd.concat([mid_join, fix_df], names=['ELEV', 'geometry'])
                    bfe_c_geom = bfe_cleaned[['geometry']]
                   
                    # spatial join cleaned geometry to original bfe df
                    clean_join = sel_bfe.sjoin(bfe_c_geom, how='left')
                    
                    # Locate bfes that were not cleaned
                    sel_bfe = clean_join.loc[clean_join['index_right'].isnull(), ['ELEV', 'geometry']]

                    # Final Cleaned BFE dataframe
                    bfe = pd.concat([bfe_cleaned, sel_bfe], ignore_index=True)
                else:
                    fix_df = fix_df[['ELEV', 'geometry']]
                    bfe_c_geom = fix_df[['geometry']]
                    clean_join = sel_bfe.sjoin(bfe_c_geom, how='left')
                    sel_bfe = clean_join.loc[clean_join['index_right'].isnull(), ['ELEV', 'geometry']]
                
                    bfe = pd.concat([fix_df, sel_bfe], ignore_index=True)
                
                
            else:
                bfe = sel_bfe[['ELEV', 'geometry']]

            # final removal of any multiline artifacts
            bfe = remove_multiline_BFE(bfe)
            
            # If conversion occured, there would by multiple linestrings that now have duplicate geometries. Need removal
            bfe = bfe.drop_duplicates('geometry')

            # repair geometries before following phase
            bfe['rgeom'] = bfe.apply(lambda x: make_valid(x.geometry), axis=1)
            bfe = bfe[['ELEV', 'rgeom']].rename(columns={'rgeom': 'geometry'}).set_geometry('geometry', crs=crs)

            # Extend BFEs over FSP Poly then reset bfe to new position
            print('Extending BFE...')
            bfe_ext, short_bfe, corrupt = bfe_extend(bfe, ae_zones, crs=crs)

            if len(corrupt) > 0:
                print(l, 'Corrupt BFE')
                print(corrupt)


            print('Splitting FSP...')
            # Split FSP Poly by extended BFEs
            ae_s = split_fsp(ae_zones, bfe_ext, crs=crs)

            print('Cleaning FSP...')
            # Remove slivers due to overlaps from extended BFEs
            ae_s = ae_s.overlay(ae_zones)
            ae_s = ae_s.loc[ae_s.geom_type == 'Polygon']
            ae_s = ae_s.loc[ae_s.area > 1] # Removing small artifacts from cleaning and split process
            ae_s = ae_s[['geometry']]
            ae_s.reset_index(inplace=True)

            ae_s_84 = ae_s.to_crs(4326)
            #ae_s_84.to_file(f'{l}_FloodZone_split.shp')

            # add short bfes to final bfe dataframe
            bfe = pd.concat([bfe_ext, short_bfe])
            bfe_84 = bfe.to_crs(4326)
            bfe_84.to_file(f'{l}_BFE.shp')

        else:
            print('No AE Zones')
            pass

        """ A Zone Merge. AE Zones with only 1 BFE will include End portions of the 
        Flood Zone and have the potential to be connect to AZones. This transition
        in Zone type is what needs to be located, so that the AE Zones that touch 
        an Azone can be converted to an AZone. Once all Azones are then accounted for
        these will be ready for triangulation. """
        if len(sel_a) > 0:
            print('AZones Present')
            a_zones = sel_a.dissolve().explode().reset_index(0, drop=True).to_crs(crs)
            
            # Identiify AE Zones and their assoicated BFEs. 
            ae_join = ae_s.sjoin(bfe)
            vals = ae_join.index.value_counts()

            # Find polygons with single BFE
            ae_single = ae_join.loc[ae_join.index.isin(vals.index[vals.lt(2)])]
            ae_single = ae_single[['geometry']]
            
            # join azones to ae zones (inner)
            ajoin = a_zones.sjoin(ae_single)[['geometry', 'index_right']]

            # Condition if any azones touch ae zones
            if len(ajoin) > 0:
                print('Joining AE Zones to A Zones')
                # ae indices to drop from original ae dataframe
                ae_drops = ajoin['index_right'].to_list()
                ae_s = ae_s.loc[~ae_s.index.isin(ae_drops)]

                # obtain geometries from matched indicies
                ajoin_geoms = ajoin.merge(ae_single, left_on='index_right', right_index=True, how='left')

                # groupby A-Zone geometry and agg intersecting ae geometry
                a_gb = ajoin_geoms.groupby(level=0)['geometry_y'].apply(list)
                a_merge = a_zones.merge(a_gb, left_index=True, right_index=True)

                # union polygons
                a_merge['new_geom'] = a_merge.apply(lambda x: unary_union([x.geometry] + x.geometry_y), axis=1)

                # create new gdf from new geometry
                a_merge = a_merge[['new_geom']].rename(columns={'new_geom': 'geometry'}).set_geometry('geometry', crs=crs)
                
                # Concat to orginal Azone dataframe
                a_zones = a_zones.loc[~a_zones.index.isin(a_merge.index)]
                all_a_zones = pd.concat([a_zones, a_merge])
                
                # Final FZ dataset
                ae_s['fz_type'] = 'AE'
                all_a_zones['fz_type'] = 'A'
                all_a_ae = pd.concat([all_a_zones, ae_s])
                all_a_ae_84 = all_a_ae[['fz_type', 'geometry']].to_crs(4326)
                
                all_a_ae_84.to_file(f'{l}_FZ.shp')
                print(f'Processing time for County {l}:', (datetime.now() - s))
                print('______________________________________________________')
                
                

            else:
                a_zones['fz_type'] = 'A'
                a_zones = a_zones[['fz_type', 'geometry']].to_crs(4326)
                a_zones.to_file(f'{l}_FZ.shp')
                print(f'Processing time for County {l}:', (datetime.now() - s))
                print('______________________________________________________')
        
        else:
            print('No A Zones')
            print(f'Processing time for County {l}:', (datetime.now() - s))
            print('______________________________________________________')
            continue
# Out:
# Processing CO_FZ\FM_08093.shp
# AE Zones
# A Zones
# X500 Zones
# No AE Zones
# AZones Present
# Processing time for County 08093: 0:00:01.848619
# ______________________________________________________
# Processing CO_FZ\FM_08119.shp
# Processing CO_BFEs\EL_08119.shp
# AE Zones
# A Zones
# X500 Zones
# Cleaning BFEs
# Extending BFE...
# polygon to line 0:00:00.001949
# ends 0:00:00.104444
# parse end points 0:00:00.355457
# create start point for extapolation 0:00:00.427717
# create extrapolation 0:00:00.586933
# intersection 0:00:00.881828
# remove empty linestrings 0:00:00.010732
# get nearest point 0:00:00.715839
# create ext_line 0:00:00.809093
# combine extension 0:00:00.903279
# new ends 0:00:00.102561
# parse new ends 0:00:00.338888
# buffer 0:00:00.396473
# symmetric difference 0:00:01.104463
# create rep point 0:00:00.463894
# final ext line 0:00:00.569319
# create final line 0:00:00.453162
# final clean up 0:00:00.018543
# Splitting FSP...
# Cleaning FSP...
# AZones Present
# Processing time for County 08119: 0:00:14.008833
# ______________________________________________________
# Processing FL_FZ\FM_12086.shp
# AE Zones
# A Zones
# X500 Zones
# No AE Zones
# AZones Present
# Processing time for County 12086: 0:00:07.333935
# ______________________________________________________
# Processing FL_FZ\FM_12011.shp
# Processing FL_BFEs\EL_12011.shp
# AE Zones
# A Zones
# X500 Zones
# Cleaning BFEs
# Extending BFE...
# polygon to line 0:00:00.000975
# ends 0:00:00.052738
# parse end points 0:00:00.173832
# create start point for extapolation 0:00:00.221681
# create extrapolation 0:00:00.287097
# intersection 0:00:00.733394
# remove empty linestrings 0:00:00.009770
# get nearest point 0:00:00.376951
# create ext_line 0:00:00.441394
# combine extension 0:00:00.304718
# new ends 0:00:00.063478
# parse new ends 0:00:00.172868
# buffer 0:00:00.207987
# symmetric difference 0:00:00.453131
# create rep point 0:00:00.231459
# final ext line 0:00:00.303699
# create final line 0:00:00.238282
# final clean up 0:00:00.013692
# Splitting FSP...
# Cleaning FSP...
# No A Zones
# Processing time for County 12011: 0:00:15.696795
# ______________________________________________________
# Processing FL_FZ\FM_12087.shp
# AE Zones
# A Zones
# X500 Zones
# No AE Zones
# No A Zones
# Processing time for County 12087: 0:00:05.121088
# ______________________________________________________
# Processing FL_FZ\FM_12051.shp
# Processing FL_BFEs\EL_12051.shp
# AE Zones
# A Zones
# X500 Zones
# Cleaning BFEs
# Extending BFE...
# polygon to line 0:00:00.025408
# ends 0:00:00.170883
# parse end points 0:00:00.539051
# create start point for extapolation 0:00:00.682608
# create extrapolation 0:00:00.908229
# intersection 0:03:31.807511
# remove empty linestrings 0:00:00.011778
# get nearest point 0:00:01.327171
# create ext_line 0:00:01.539976
# combine extension 0:00:01.169919
# new ends 0:00:00.175740
# parse new ends 0:00:00.541004
# buffer 0:00:00.646478
# symmetric difference 0:01:06.400375
# create rep point 0:00:01.006836
# final ext line 0:00:00.935566
# create final line 0:00:00.732439
# final clean up 0:00:00.022460
# Splitting FSP...
# Cleaning FSP...
# AZones Present
# Processing time for County 12051: 0:15:15.075819
# ______________________________________________________
# Processing FL_FZ\FM_12099.shp
# Processing FL_BFEs\EL_12099.shp
# AE Zones
# A Zones
# X500 Zones
# Cleaning BFEs
# Extending BFE...
# polygon to line 0:00:00.009754
# ends 0:00:00.217796
# parse end points 0:00:00.977506
# create start point for extapolation 0:00:00.869139
# create extrapolation 0:00:01.172864
# intersection 0:00:09.402821
# remove empty linestrings 0:00:00.011745
# get nearest point 0:00:01.503892
# create ext_line 0:00:01.959997
# combine extension 0:00:01.203072
# new ends 0:00:00.212878
# parse new ends 0:00:00.678733
# buffer 0:00:00.813458
# symmetric difference 0:00:47.381826
# create rep point 0:00:00.922851
# final ext line 0:00:01.192886
# create final line 0:00:00.926743
# final clean up 0:00:00.025425
# Splitting FSP...
# Cleaning FSP...
# AZones Present
# Processing time for County 12099: 0:02:41.099052
# ______________________________________________________
# Processing LA_FZ\FM_22071.shp
# Processing LA_BFEs\EL_22071.shp
# AE Zones
# A Zones
# X500 Zones
# Cleaning BFEs
# Extending BFE...
# polygon to line 0:00:00.008780
# ends 0:00:00.145476
# parse end points 0:00:00.481463
# create start point for extapolation 0:00:00.591780
# create extrapolation 0:00:00.778308
# intersection 0:00:03.316453
# remove empty linestrings 0:00:00.011670
# get nearest point 0:00:01.020995
# create ext_line 0:00:01.457030
# combine extension 0:00:00.806672
# new ends 0:00:00.146484
# parse new ends 0:00:00.477519
# buffer 0:00:00.742235
# symmetric difference 0:00:14.572770
# create rep point 0:00:00.730450
# final ext line 0:00:00.834038
# create final line 0:00:00.683547
# final clean up 0:00:00.021503
# Splitting FSP...
# Cleaning FSP...
# No A Zones
# Processing time for County 22071: 0:00:56.655747
# ______________________________________________________
# Processing LA_FZ\FM_22051.shp
# Processing LA_BFEs\EL_22051.shp
# AE Zones
# A Zones
# X500 Zones
# Cleaning BFEs
# Extending BFE...
# polygon to line 0:00:00.009734
# ends 0:00:00.240263
# parse end points 0:00:01.026372
# create start point for extapolation 0:00:00.937447
# create extrapolation 0:00:01.274484
# intersection 0:00:08.427159
# remove empty linestrings 0:00:00.012727
# get nearest point 0:00:01.614227
# create ext_line 0:00:02.126960
# combine extension 0:00:01.273458
# new ends 0:00:00.231441
# parse new ends 0:00:00.744179
# buffer 0:00:00.898384
# symmetric difference 0:00:39.217804
# create rep point 0:00:01.006299
# final ext line 0:00:01.589856
# create final line 0:00:01.009760
# final clean up 0:00:00.030287
# Splitting FSP...
# Cleaning FSP...
# No A Zones
# Processing time for County 22051: 0:01:47.002863
# ______________________________________________________
# Processing LA_FZ\FM_22075.shp
# Processing LA_BFEs\EL_22075.shp
# AE Zones
# A Zones
# X500 Zones
# Cleaning BFEs
# Extending BFE...
# polygon to line 0:00:00.005904
# ends 0:00:00.036088
# parse end points 0:00:00.107857
# create start point for extapolation 0:00:00.130859
# create extrapolation 0:00:00.174388
# intersection 0:00:00.439866
# remove empty linestrings 0:00:00.009767
# get nearest point 0:00:00.224604
# create ext_line 0:00:00.253936
# combine extension 0:00:00.174803
# new ends 0:00:00.035119
# parse new ends 0:00:00.102447
# buffer 0:00:00.127901
# symmetric difference 0:00:01.900371
# create rep point 0:00:00.140622
# final ext line 0:00:00.181613
# create final line 0:00:00.134772
# final clean up 0:00:00.011696
# Splitting FSP...
# Cleaning FSP...
# AZones Present
# Processing time for County 22075: 0:00:14.012132
# ______________________________________________________
# Processing LA_FZ\FM_22087.shp
# Processing LA_BFEs\EL_22087.shp
# AE Zones
# A Zones
# X500 Zones
# Cleaning BFEs
# Extending BFE...
# polygon to line 0:00:00.005855
# ends 0:00:00.105487
# parse end points 0:00:00.358394
# create start point for extapolation 0:00:00.421879
# create extrapolation 0:00:00.570328
# intersection 0:00:01.933091
# remove empty linestrings 0:00:00.010735
# get nearest point 0:00:00.705062
# create ext_line 0:00:00.785180
# combine extension 0:00:00.566385
# new ends 0:00:00.100599
# parse new ends 0:00:00.321289
# buffer 0:00:00.391578
# symmetric difference 0:00:08.568399
# create rep point 0:00:00.730414
# final ext line 0:00:00.562480
# create final line 0:00:00.445312
# final clean up 0:00:00.018563
# Splitting FSP...
# Cleaning FSP...
# No A Zones
# Processing time for County 22087: 0:00:33.479380
# ______________________________________________________
# Processing LA_FZ\FM_22103.shp
# Processing LA_BFEs\EL_22103.shp
# AE Zones
# A Zones
# X500 Zones
# Cleaning BFEs
# Extending BFE...
# polygon to line 0:00:00.000953
# ends 0:00:00.167974
# parse end points 0:00:00.536150
# create start point for extapolation 0:00:00.683554
# create extrapolation 0:00:00.911109
# intersection 0:00:01.543973
# remove empty linestrings 0:00:00.012654
# get nearest point 0:00:00.950239
# create ext_line 0:00:01.060514
# combine extension 0:00:01.040996
# new ends 0:00:00.131853
# parse new ends 0:00:00.427754
# buffer 0:00:00.526331
# symmetric difference 0:00:02.202622
# create rep point 0:00:00.574253
# final ext line 0:00:00.734358
# create final line 0:00:00.575223
# final clean up 0:00:00.020475
# Splitting FSP...
# Cleaning FSP...
# AZones Present
# Processing time for County 22103: 0:00:19.267032
# ______________________________________________________
# Processing LA_FZ\FM_22057.shp
# Processing LA_BFEs\EL_22057.shp
# AE Zones
# A Zones
# X500 Zones
# Cleaning BFEs
# Extending BFE...
# polygon to line 0:00:00.000984
# ends 0:00:00.002888
# parse end points 0:00:00.007759
# create start point for extapolation 0:00:00.010789
# create extrapolation 0:00:00.011699
# intersection 0:00:00.014637
# remove empty linestrings 0:00:00.008803
# get nearest point 0:00:00.014669
# create ext_line 0:00:00.017517
# combine extension 0:00:00.010746
# new ends 0:00:00.003899
# parse new ends 0:00:00.009758
# buffer 0:00:00.009784
# symmetric difference 0:00:00.014613
# create rep point 0:00:00.013685
# final ext line 0:00:00.012723
# create final line 0:00:00.008778
# final clean up 0:00:00.007822
# Splitting FSP...
# Cleaning FSP...
# AZones Present
# Processing time for County 22057: 0:00:03.973624
# ______________________________________________________
# Processing LA_FZ\FM_22089.shp
# Processing LA_BFEs\EL_22089.shp
# AE Zones
# A Zones
# X500 Zones
# Cleaning BFEs
# Extending BFE...
# polygon to line 0:00:00.000944
# ends 0:00:00.003935
# parse end points 0:00:00.010753
# create start point for extapolation 0:00:00.012668
# create extrapolation 0:00:00.015601
# intersection 0:00:00.018602
# remove empty linestrings 0:00:00.008773
# get nearest point 0:00:00.021452
# create ext_line 0:00:00.023470
# combine extension 0:00:00.013725
# new ends 0:00:00.004917
# parse new ends 0:00:00.011668
# buffer 0:00:00.013763
# symmetric difference 0:00:00.016535
# create rep point 0:00:00.014649
# final ext line 0:00:00.016640
# create final line 0:00:00.011675
# final clean up 0:00:00.008801
# Splitting FSP...
# Cleaning FSP...
# AZones Present
# Processing time for County 22089: 0:00:03.798834
# ______________________________________________________
# Processing LA_FZ\FM_22095.shp
# Processing LA_BFEs\EL_22095.shp
# AE Zones
# A Zones
# X500 Zones
# Cleaning BFEs
# Extending BFE...
# polygon to line 0:00:00.000952
# ends 0:00:00.003917
# parse end points 0:00:00.012712
# create start point for extapolation 0:00:00.016593
# create extrapolation 0:00:00.019538
# intersection 0:00:00.022501
# remove empty linestrings 0:00:00.009712
# get nearest point 0:00:00.025419
# create ext_line 0:00:00.028321
# combine extension 0:00:00.020490
# new ends 0:00:00.004888
# parse new ends 0:00:00.013676
# buffer 0:00:00.014700
# symmetric difference 0:00:00.021522
# create rep point 0:00:00.017517
# final ext line 0:00:00.020472
# create final line 0:00:00.014702
# final clean up 0:00:00.007785
# Splitting FSP...
# Cleaning FSP...
# No A Zones
# Processing time for County 22095: 0:00:00.809563
# ______________________________________________________
# Processing LA_FZ\FM_22105.shp
# Processing LA_BFEs\EL_22105.shp
# AE Zones
# A Zones
# X500 Zones
# Cleaning BFEs
# Extending BFE...
# polygon to line 0:00:00.002915
# ends 0:00:00.133770
# parse end points 0:00:00.431643
# create start point for extapolation 0:00:00.645508
# create extrapolation 0:00:00.827138
# intersection 0:00:01.900435
# remove empty linestrings 0:00:00.011648
# get nearest point 0:00:01.028346
# create ext_line 0:00:01.380829
# combine extension 0:00:00.757843
# new ends 0:00:00.134770
# parse new ends 0:00:00.429707
# buffer 0:00:00.525383
# symmetric difference 0:00:04.588868
# create rep point 0:00:00.591802
# final ext line 0:00:00.751931
# create final line 0:00:00.603539
# final clean up 0:00:00.020484
# Splitting FSP...
# Cleaning FSP...
# AZones Present
# Processing time for County 22105: 0:00:26.079052
# ______________________________________________________

# %%
df = pd.DataFrame({'ELEV': [10, 10, 11, 15]})
df1 = pd.DataFrame({'ELEV': [10, 10, 11, 10, 10, 10, 10, 10, 10, 10, 10, 10, 15, 10, 10, 10, 10, 10, 10, 10]})

# %%
df.describe()
# Out:
#             ELEV
# count   4.000000
# mean   11.500000
# std     2.380476
# min    10.000000
# 25%    10.000000
# 50%    10.500000
# 75%    12.000000
# max    15.000000

# %%
df1.describe()
# Out:
#             ELEV
# count  20.000000
# mean   10.300000
# std     1.128576
# min    10.000000
# 25%    10.000000
# 50%    10.000000
# 75%    10.000000
# max    15.000000
